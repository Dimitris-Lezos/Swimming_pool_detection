# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
images_path = 'C:\\Users/Intel PC G5900/Desktop/swimmingPool/training/images/'
image_name = '000000147.jpg'
image_full_path = images_path+image_name

# %%
os.listdir('../Data/')
# Out:
# ['000000055.jpg', '000000148.jpg']

# %%
window_name = 'Pool Satelite Photo'
image = cv2.imread(image_full_path)
plot_image_hist(image)
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
lower_blue = (90, 50, 50)
upper_blue = (130, 255, 255)
mask = cv2.inRange(hsv, lower_blue, upper_blue)
result = cv2.bitwise_and(image, image, mask=mask)
grey = cv2.cvtColor(result, cv2.COLOR_BGR2GRAY)
# Threshold the image to keep only pixels greater than 0
_, thresholded_image = cv2.threshold(grey, 98, 100, cv2.THRESH_BINARY)
# Find the contours of the non-zero pixels
contours, _ = cv2.findContours(thresholded_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# %%
show_image_with_waitkey(thresholded_image, window_name)

# %%
show_image_with_waitkey2(image, window_name, contours)

# %%
plot_image_hist(image)

# %%
channel_means = np.mean(image, axis=(0, 1))

# %%
channel_means
# Out:
# array([103.53435906, 103.46107701,  97.67177535])

# %%
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
#hsv[:, :, 0] = 255

lower_bound = (90, 120, 60)
upper_bound = (130, 255, 255)

# Create mask for cyan
mask = cv2.inRange(hsv, lower_bound, upper_bound)
plt.imshow(mask)
plt.show()
# image = cv2.cvtColor(mask, cv2.COLOR_HSV2BGR)
# plt.imshow(image)
# plt.show()
